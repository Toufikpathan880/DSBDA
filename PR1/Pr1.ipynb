# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Pclass'] = df['Pclass'].astype('category')
df['Survived'] = df['Survived'].astype('category')
df['Sex'] = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')

# %%
df_encoded = pd.get_dummies(df, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)

# %%
df_encoded
# Out:
#      PassengerId Survived                                               Name  \
# 0              1        0                            Braund, Mr. Owen Harris
# 1              2        1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3        1                             Heikkinen, Miss. Laina
# 3              4        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5        0                           Allen, Mr. William Henry
# ..           ...      ...                                                ...
# 886          887        0                              Montvila, Rev. Juozas
# 887          888        1                       Graham, Miss. Margaret Edith
# 888          889        0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890        1                              Behr, Mr. Karl Howell
# 890          891        0                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare Cabin  Sex_male  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN      True
# 1    38.0      1      0          PC 17599  71.2833   C85     False
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN     False
# 3    35.0      1      0            113803  53.1000  C123     False
# 4    35.0      0      0            373450   8.0500   NaN      True
# ..    ...    ...    ...               ...      ...   ...       ...
# 886  27.0      0      0            211536  13.0000   NaN      True
# 887  19.0      0      0            112053  30.0000   B42     False
# 888   NaN      1      2        W./C. 6607  23.4500   NaN     False
# 889  26.0      0      0            111369  30.0000  C148      True
# 890  32.0      0      0            370376   7.7500   NaN      True
#
#      Embarked_Q  Embarked_S  Pclass_2  Pclass_3
# 0         False        True     False      True
# 1         False       False     False     False
# 2         False        True     False      True
# 3         False        True     False     False
# 4         False        True     False      True
# ..          ...         ...       ...       ...
# 886       False        True      True     False
# 887       False        True     False     False
# 888       False        True     False      True
# 889       False       False     False     False
# 890        True       False     False      True
#
# [891 rows x 14 columns]

# %%
def fun1(value):
    if (value == "male"):
        return 1
    elif (value == "female"):
        return 0
    else:
        pass

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Sex"] = df["Sex"].apply(fun1)

# %%
df.head(10)
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
# 5            6        0      3
# 6            7        0      1
# 7            8        0      3
# 8            9        1      3
# 9           10        1      2
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0      1      0
# 2                             Heikkinen, Miss. Laina   0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0      1      0
# 4                           Allen, Mr. William Henry   1  35.0      0      0
# 5                                   Moran, Mr. James   1   NaN      0      0
# 6                            McCarthy, Mr. Timothy J   1  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard   1   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   0  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)   0  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
# 6             17463  51.8625   E46        S
# 7            349909  21.0750   NaN        S
# 8            347742  11.1333   NaN        S
# 9            237736  30.0708   NaN        C

# %%
def fun2(value):
    if (np.isnan(value) == False):
        return int(value)

# %%
df["Age"] = df["Age"].apply(fun2)

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0      1      0
# 2                             Heikkinen, Miss. Laina   0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0      1      0
# 4                           Allen, Mr. William Henry   1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df_age_greater_than_25 = df[df["Age"] > 25.0]

# %%
df_age_greater_than_25.head()
# Out:
#    PassengerId Survived Pclass  \
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
# 6            7        0      1
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0      1      0
# 2                             Heikkinen, Miss. Laina   0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0      1      0
# 4                           Allen, Mr. William Henry   1  35.0      0      0
# 6                            McCarthy, Mr. Timothy J   1  54.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 6             17463  51.8625   E46        S

# %%
df.columns = ["passenger_id", "survived", "p_class", "name", "sex", "age", "sib_sp", "parch", "ticket", "fare", "cabin", "embarked"]

# %%
df.head()
# Out:
#    passenger_id survived p_class  \
# 0             1        0       3
# 1             2        1       1
# 2             3        1       3
# 3             4        1       1
# 4             5        0       3
#
#                                                 name sex   age  sib_sp  parch  \
# 0                            Braund, Mr. Owen Harris   1  22.0       1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0       1      0
# 2                             Heikkinen, Miss. Laina   0  26.0       0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0       1      0
# 4                           Allen, Mr. William Henry   1  35.0       0      0
#
#              ticket     fare cabin embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df["age"].value_counts()
# Out:
# age
# 24.0    31
# 28.0    27
# 22.0    27
# 30.0    27
# 18.0    26
#         ..
# 66.0     1
# 12.0     1
# 53.0     1
# 80.0     1
# 74.0     1
# Name: count, Length: 71, dtype: int64

# %%
def fun3(value):
    if (value < 20):
        return "teenager"
    elif (value >= 20 and value < 40):
        return "young"
    elif (value >= 40 and value < 60):
        return "middle aged"
    elif (value >= 60):
        return "senior citizen"
    else:
        pass

# %%
df["age"] = df["age"].apply(fun3)

# %%
df.head(10)
# Out:
#    passenger_id survived p_class  \
# 0             1        0       3
# 1             2        1       1
# 2             3        1       3
# 3             4        1       1
# 4             5        0       3
# 5             6        0       3
# 6             7        0       1
# 7             8        0       3
# 8             9        1       3
# 9            10        1       2
#
#                                                 name sex          age  sib_sp  \
# 0                            Braund, Mr. Owen Harris   1        young       1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   0        young       1
# 2                             Heikkinen, Miss. Laina   0        young       0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   0        young       1
# 4                           Allen, Mr. William Henry   1        young       0
# 5                                   Moran, Mr. James   1         None       0
# 6                            McCarthy, Mr. Timothy J   1  middle aged       0
# 7                     Palsson, Master. Gosta Leonard   1     teenager       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   0        young       0
# 9                Nasser, Mrs. Nicholas (Adele Achem)   0     teenager       1
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C
